# %% [markdown]
# <a href="https://colab.research.google.com/github/dursuninel/Cat-vs-Dog-AI-CNN/blob/main/Cat_vs_Dog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras import layers
import cv2, os
from tqdm import tqdm
from random import shuffle
import shutil

# %%
# !wget "https://cainvas-static.s3.amazonaws.com/media/user_data/tanmay/dogvcat.zip"
# !unzip -qo dogvcat.zip
# Out:
# --2023-12-15 07:31:42--  https://cainvas-static.s3.amazonaws.com/media/user_data/tanmay/dogvcat.zip
# Resolving cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)... 52.219.156.115, 52.219.62.84, 52.219.156.75, ...
# Connecting to cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)|52.219.156.115|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60547127 (58M) [application/zip]
# Saving to: ‘dogvcat.zip’
#
# dogvcat.zip         100%[===================>]  57.74M  11.7MB/s    in 6.3s
#
# 2023-12-15 07:31:50 (9.13 MB/s) - ‘dogvcat.zip’ saved [60547127/60547127]

# %%
train_dir= "./datset/training"
test_dir= "./datset/testing/"
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, validation_split= 0.2)
train_generator = train_datagen.flow_from_directory(train_dir, target_size=(50,50), color_mode='grayscale', batch_size=20, class_mode='binary', subset= 'training')
val_generator = train_datagen.flow_from_directory(train_dir, target_size=(50,50), color_mode='grayscale', batch_size=20, class_mode='binary', subset= 'validation')
# Out:
# Found 19860 images belonging to 2 classes.
# Found 4963 images belonging to 2 classes.

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(16, kernel_size=(3,3), activation='relu',input_shape=(50,50,1), padding='same'))
# model.add(LeakyReLU(alpha=0.1))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2), padding='same'))
model.add(tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation='relu', padding='same'))
# model.add(tf.keras.activations.relu(alpha=0.1))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2), padding='same'))
model.add(tf.keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu', padding='same'))
# model.add(tf.keras.activations.relu(alpha=0.1))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2), padding='same'))
model.add(tf.keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu', padding='same'))
# model.add(tf.keras.activations.relu(alpha=0.1))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2), padding='same'))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
# model.add(tf.keras.activations.relu(alpha=0.1))
model.add(Dropout(0.5))
model.add(tf.keras.layers.Dense(256, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 50, 50, 16)        160
#
#  max_pooling2d (MaxPooling2  (None, 25, 25, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 25, 25, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 13, 13, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 64)          36928
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 4, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 128)               131200
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 224705 (877.75 KB)
# Trainable params: 224705 (877.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Model Compilation
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit_generator(train_generator, epochs=50, validation_data=val_generator, validation_steps=50)
# Out:
# <ipython-input-6-0430d01042f4>:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, epochs=50, validation_data=val_generator, validation_steps=50)
# Epoch 1/50
# 993/993 [==============================] - 21s 14ms/step - loss: 0.6905 - accuracy: 0.5207 - val_loss: 0.6858 - val_accuracy: 0.4760
# Epoch 2/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.6669 - accuracy: 0.5906 - val_loss: 0.6426 - val_accuracy: 0.6190
# Epoch 3/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.6139 - accuracy: 0.6635 - val_loss: 0.5822 - val_accuracy: 0.6960
# Epoch 4/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.5587 - accuracy: 0.7158 - val_loss: 0.5423 - val_accuracy: 0.7300
# Epoch 5/50
# 993/993 [==============================] - 14s 14ms/step - loss: 0.5167 - accuracy: 0.7469 - val_loss: 0.4985 - val_accuracy: 0.7610
# Epoch 6/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.4836 - accuracy: 0.7725 - val_loss: 0.4657 - val_accuracy: 0.7850
# Epoch 7/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.4564 - accuracy: 0.7845 - val_loss: 0.4437 - val_accuracy: 0.7860
# Epoch 8/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.4417 - accuracy: 0.7936 - val_loss: 0.4233 - val_accuracy: 0.8150
# Epoch 9/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.4179 - accuracy: 0.8066 - val_loss: 0.4406 - val_accuracy: 0.7980
# Epoch 10/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.4099 - accuracy: 0.8174 - val_loss: 0.4381 - val_accuracy: 0.7910
# Epoch 11/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.3946 - accuracy: 0.8225 - val_loss: 0.4076 - val_accuracy: 0.8250
# Epoch 12/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.3767 - accuracy: 0.8297 - val_loss: 0.4377 - val_accuracy: 0.7900
# Epoch 13/50
# 993/993 [==============================] - 14s 14ms/step - loss: 0.3634 - accuracy: 0.8386 - val_loss: 0.4108 - val_accuracy: 0.8160
# Epoch 14/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.3556 - accuracy: 0.8413 - val_loss: 0.3992 - val_accuracy: 0.8120
# Epoch 15/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.3463 - accuracy: 0.8458 - val_loss: 0.4143 - val_accuracy: 0.8100
# Epoch 16/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.3291 - accuracy: 0.8517 - val_loss: 0.3735 - val_accuracy: 0.8440
# Epoch 17/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.3220 - accuracy: 0.8587 - val_loss: 0.3881 - val_accuracy: 0.8290
# Epoch 18/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.3077 - accuracy: 0.8672 - val_loss: 0.3694 - val_accuracy: 0.8210
# Epoch 19/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.3013 - accuracy: 0.8694 - val_loss: 0.4139 - val_accuracy: 0.8120
# Epoch 20/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.2984 - accuracy: 0.8711 - val_loss: 0.3994 - val_accuracy: 0.8290
# Epoch 21/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.2851 - accuracy: 0.8783 - val_loss: 0.4152 - val_accuracy: 0.8150
# Epoch 22/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.2727 - accuracy: 0.8835 - val_loss: 0.4458 - val_accuracy: 0.8010
# Epoch 23/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.2682 - accuracy: 0.8843 - val_loss: 0.4151 - val_accuracy: 0.8140
# Epoch 24/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.2642 - accuracy: 0.8892 - val_loss: 0.4009 - val_accuracy: 0.8250
# Epoch 25/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.2470 - accuracy: 0.8958 - val_loss: 0.3983 - val_accuracy: 0.8190
# Epoch 26/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.2399 - accuracy: 0.9015 - val_loss: 0.4320 - val_accuracy: 0.8100
# Epoch 27/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.2362 - accuracy: 0.9024 - val_loss: 0.4218 - val_accuracy: 0.8290
# Epoch 28/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.2339 - accuracy: 0.9024 - val_loss: 0.4432 - val_accuracy: 0.8110
# Epoch 29/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.2228 - accuracy: 0.9048 - val_loss: 0.4345 - val_accuracy: 0.8100
# Epoch 30/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.2144 - accuracy: 0.9107 - val_loss: 0.4361 - val_accuracy: 0.8020
# Epoch 31/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.2119 - accuracy: 0.9110 - val_loss: 0.4523 - val_accuracy: 0.8050
# Epoch 32/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.2094 - accuracy: 0.9121 - val_loss: 0.4085 - val_accuracy: 0.8220
# Epoch 33/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.2007 - accuracy: 0.9177 - val_loss: 0.4781 - val_accuracy: 0.8200
# Epoch 34/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.1936 - accuracy: 0.9191 - val_loss: 0.4436 - val_accuracy: 0.8330
# Epoch 35/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.1908 - accuracy: 0.9212 - val_loss: 0.4759 - val_accuracy: 0.8030
# Epoch 36/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.1867 - accuracy: 0.9232 - val_loss: 0.4462 - val_accuracy: 0.8310
# Epoch 37/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.1847 - accuracy: 0.9253 - val_loss: 0.4357 - val_accuracy: 0.8290
# Epoch 38/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.1748 - accuracy: 0.9295 - val_loss: 0.4464 - val_accuracy: 0.8360
# Epoch 39/50
# 993/993 [==============================] - 15s 15ms/step - loss: 0.1737 - accuracy: 0.9287 - val_loss: 0.4667 - val_accuracy: 0.8290
# Epoch 40/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.1725 - accuracy: 0.9294 - val_loss: 0.4882 - val_accuracy: 0.8150
# Epoch 41/50
# 993/993 [==============================] - 12s 13ms/step - loss: 0.1619 - accuracy: 0.9349 - val_loss: 0.4858 - val_accuracy: 0.8280
# Epoch 42/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.1648 - accuracy: 0.9336 - val_loss: 0.4454 - val_accuracy: 0.8180
# Epoch 43/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.1554 - accuracy: 0.9361 - val_loss: 0.4569 - val_accuracy: 0.8230
# Epoch 44/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.1537 - accuracy: 0.9389 - val_loss: 0.4736 - val_accuracy: 0.8340
# Epoch 45/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.1507 - accuracy: 0.9391 - val_loss: 0.3821 - val_accuracy: 0.8390
# Epoch 46/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.1496 - accuracy: 0.9407 - val_loss: 0.4364 - val_accuracy: 0.8220
# Epoch 47/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.1498 - accuracy: 0.9389 - val_loss: 0.5662 - val_accuracy: 0.8120
# Epoch 48/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.1449 - accuracy: 0.9401 - val_loss: 0.5542 - val_accuracy: 0.8120
# Epoch 49/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.1434 - accuracy: 0.9417 - val_loss: 0.5181 - val_accuracy: 0.8250
# Epoch 50/50
# 993/993 [==============================] - 13s 13ms/step - loss: 0.1394 - accuracy: 0.9451 - val_loss: 0.5244 - val_accuracy: 0.8250

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
def Single_Image_Prediction(file):
#     image = load_img(file, color_mode='rgb', target_size=(128, 128))
    image = cv2.imread(file)
    plt.imshow(image)
    plt.show()
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    img_arr = img_to_array(image)
    img_arr = img_arr/255.
    np_image = np.expand_dims(img_arr, axis=0)
    return np_image
image = Single_Image_Prediction('./datset/testing/6.jpg')

pred_value = model.predict(tf.image.resize(image, (50, 50)))

if pred_value < 0.5:
    print('Kedi')
else:
    print('Köpek')
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Kedi

# %% [markdown]
# # Yeni Bölüm
